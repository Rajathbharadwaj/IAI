# %%
# Gym stuff
import gym
import gym_anytrading
from stable_baselines3 import PPO

# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C, PPO

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# read Reliance stock with indicators calculated.
df = pd.read_csv('Reliance.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'SUPERT_7_1.0', 'SUPERTd_7_1.0', 'SUPERTl_7_1.0',
#        'SUPERTs_7_1.0', 'SMA_5', 'WMA_10', 'SMA_14', 'WMA_28', 'SMA_44',
#        'PSARl_0.02_0.2', 'PSARs_0.02_0.2', 'PSARaf_0.02_0.2',
#        'PSARr_0.02_0.2'],
#       dtype='object')

# %%
df['Date']
# Out:
# 0       1996-01-01 00:00:00+05:30
# 1       1996-01-02 00:00:00+05:30
# 2       1996-01-03 00:00:00+05:30
# 3       1996-01-04 00:00:00+05:30
# 4       1996-01-05 00:00:00+05:30
#                   ...
# 6790    2023-01-02 00:00:00+05:30
# 6791    2023-01-03 00:00:00+05:30
# 6792    2023-01-04 00:00:00+05:30
# 6793    2023-01-05 00:00:00+05:30
# 6794    2023-01-06 00:00:00+05:30
# Name: Date, Length: 6795, dtype: object

# %%
# some data preprocessing
df.set_index('Date', inplace=True)
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 1996-01-01 00:00:00+05:30  10.439797  10.495815  10.371046  10.477991
# 1996-01-02 00:00:00+05:30  10.452527  10.503452  10.320119  10.396508
# 1996-01-03 00:00:00+05:30  10.567110  11.048360  10.452527  10.475444
# 1996-01-04 00:00:00+05:30  10.376140  10.409242  10.238640  10.378686
# 1996-01-05 00:00:00+05:30  10.337946  10.337946  10.218270  10.307390
#
#                               Volume  Dividends  Stock Splits  SUPERT_7_1.0  \
# Date
# 1996-01-01 00:00:00+05:30   48051995        0.0           0.0           0.0
# 1996-01-02 00:00:00+05:30   77875009        0.0           0.0           NaN
# 1996-01-03 00:00:00+05:30   96602936        0.0           0.0           NaN
# 1996-01-04 00:00:00+05:30  100099436        0.0           0.0           NaN
# 1996-01-05 00:00:00+05:30   76935930        0.0           0.0           NaN
#
#                            SUPERTd_7_1.0  SUPERTl_7_1.0  SUPERTs_7_1.0  \
# Date
# 1996-01-01 00:00:00+05:30              1            NaN            NaN
# 1996-01-02 00:00:00+05:30              1            NaN            NaN
# 1996-01-03 00:00:00+05:30              1            NaN            NaN
# 1996-01-04 00:00:00+05:30              1            NaN            NaN
# 1996-01-05 00:00:00+05:30              1            NaN            NaN
#
#                                SMA_5  WMA_10  SMA_14  WMA_28  SMA_44  \
# Date
# 1996-01-01 00:00:00+05:30        NaN     NaN     NaN     NaN     NaN
# 1996-01-02 00:00:00+05:30        NaN     NaN     NaN     NaN     NaN
# 1996-01-03 00:00:00+05:30        NaN     NaN     NaN     NaN     NaN
# 1996-01-04 00:00:00+05:30        NaN     NaN     NaN     NaN     NaN
# 1996-01-05 00:00:00+05:30  10.407204     NaN     NaN     NaN     NaN
#
#                            PSARl_0.02_0.2  PSARs_0.02_0.2  PSARaf_0.02_0.2  \
# Date
# 1996-01-01 00:00:00+05:30             NaN             NaN             0.02
# 1996-01-02 00:00:00+05:30       10.320119             NaN             0.02
# 2023-01-06 00:00:00+05:30               0  44.157914
#
# [5 rows x 21 columns]

# %%
df.rename(columns={'close': 'Close', 'open':'Open', 'low':'Low', 'volume':'Volume'}, inplace=True)

# %%
df.shape
# Out:
# (6795, 20)

# %%
# create a stock env with the dataset with data to be considered from 5 to 5000 samples with the previous history of 5
env = gym.make('stocks-v0', df=df, frame_bound=(5,5000), window_size=5)

# %%
env.signal_features.shape
# Out:
# (5000, 2)

# %%
env.env.reward_range
# Out:
# (-inf, inf)

# %%
# perform some random action from the action space

state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': 754.8057470321658, 'total_profit': 2.1286115494308044e-07, 'position': 1}

# %%
# create a env and wrap it in a dummy vectorized env for stablebaselines3 to apply different algorithms
env_maker = lambda: gym.make('stocks-v0', df=df, frame_bound=(10,5000), window_size=10)
env = DummyVecEnv([env_maker])

# %%
df['SUPERTd_7_1.0'].value_counts()
# Out:
#  1    3577
# -1    3218
# Name: SUPERTd_7_1.0, dtype: int64

# %%
import pandas_ta as ta

# %%
# calculate and append RSI indicator to the dataframe
df['RSI'] = df.ta.rsi(14)

# %%
df['PSARr_0.02_0.2'].value_counts()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'SUPERT_7_1.0', 'SUPERTd_7_1.0', 'SUPERTl_7_1.0', 'SUPERTs_7_1.0',
#        'SMA_5', 'WMA_10', 'SMA_14', 'WMA_28', 'SMA_44', 'PSARl_0.02_0.2',
#        'PSARs_0.02_0.2', 'PSARaf_0.02_0.2', 'PSARr_0.02_0.2', 'RSI'],
#       dtype='object')

# %%
# REMOVE all NaN values and set it to 0
df.fillna(0, inplace=True)

# %%
# Env to consider different technical indicators calculated
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Low', 'Volume','SMA_5', 'RSI', 'SUPERTd_7_1.0', 'PSARr_0.02_0.2']].fillna(0).to_numpy()[start:end]
    return prices, signal_features

# %%
# Creating custom env to add the indicators specified
from gym_anytrading.envs import StocksEnv

class MyCustomEnv(StocksEnv):
    _process_data = add_signals
    
env2 = MyCustomEnv(df=df, window_size=12, frame_bound=(12,5000))

# %%
env2.signal_features
# Out:
# array([[ 1.03710464e+01,  4.80519950e+07,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 1.03201192e+01,  7.78750090e+07,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 1.04525269e+01,  9.66029360e+07,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 3.94652159e+02,  5.36476900e+06,  4.04600623e+02,
#          3.75337633e+01, -1.00000000e+00,  0.00000000e+00],
#        [ 3.93413934e+02,  7.31637400e+06,  4.01043170e+02,
#          3.99135617e+01, -1.00000000e+00,  1.00000000e+00],
#        [ 3.99319180e+02,  7.98026400e+06,  4.02414697e+02,
#          4.71081063e+01,  1.00000000e+00,  0.00000000e+00]])

# %%
import wandb
from wandb.integration.sb3 import WandbCallback

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
# create a config and wandb init to setup weights and biases tracking of each steps
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 1000000,
    "env_id": "Stocks-v0",
}
run = wandb.init(
    project="sb3-Latest",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)

# create the model with A2C

model_with_signals_A2C = A2C(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}")
model_with_signals_A2C.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        model_save_path=f"models/{run.id}",
        verbose=2,
    ),
)
run.finish()
# Out:
# Finishing last run (ID:21h1k183) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/fps</td><td>▃▄▁▃▃▄▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▂▃▂▄▅▅▃▅▆▃▆▆▆▅▅▅▆█▇▆█▅▆▇█▆▇▆▇█▇▇▆▇█</td></tr><tr><td>train/explained_variance</td><td>▅▆▅▄▄▅▅▅▆▆▄▆▅▅▄▅▅▅▆▅▅▅▅▆▆▆▅▆▆▆▆▅▁▆▅▆▆█▆▇</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/policy_loss</td><td>▇▁▆▆▅▂▅▅▅▆▅▆▅█▅▅▅▅▅▅▅▅▅▅▅▅▅▇▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>train/value_loss</td><td>▅▇▂▁▁▄▁▁▁▁▁▁▁▃▁▄▁▁▁▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁█▁▁▁▄▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>115000</td></tr><tr><td>time/fps</td><td>2907.0</td></tr><tr><td>train/entropy_loss</td><td>-0.03028</td></tr><tr><td>train/explained_variance</td><td>0.43294</td></tr><tr><td>train/learning_rate</td><td>0.0007</td></tr><tr><td>train/policy_loss</td><td>-0.0318</td></tr><tr><td>train/value_loss</td><td>19.21817</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pretty-bush-1</strong>: <a href="https://wandb.ai/full-metal/sb3-New/runs/21h1k183" target="_blank">https://wandb.ai/full-metal/sb3-New/runs/21h1k183</a><br/>Synced 7 W&B file(s), 0 media file(s), 2 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230106_125430-21h1k183/logs</code>
# Successfully finished last run (ID:21h1k183). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016720192349998796, max=1.0…
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/Users/rajathdb/D/RL Trading/wandb/run-20230106_125551-l57u9tn8</code>
# Syncing run <strong><a href="https://wandb.ai/full-metal/sb3-Latest/runs/l57u9tn8" target="_blank">northern-galaxy-1</a></strong> to <a href="https://wandb.ai/full-metal/sb3-Latest" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Logging to runs/l57u9tn8/A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 2744     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | -0.00782 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.417    |
# |    value_loss         | 0.649    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2816     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0.023    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.201   |
# |    value_loss         | 0.418    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2769     |
# |    iterations         | 300      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | -74.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0458  |
# |    value_loss         | 0.0424   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2748     |
# |    iterations         | 400      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | -0.276   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0602  |
# |    value_loss         | 0.0194   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2745     |
# |    iterations         | 500      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | 0.238    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.423    |
# |    value_loss         | 0.434    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2736     |
# |    iterations         | 600      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.672   |
# |    explained_variance | 0.00552  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.72     |
# |    value_loss         | 14.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2772     |
# |    iterations         | 700      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | -0.011   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 3.07     |
# |    value_loss         | 30.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2791     |
# |    iterations         | 800      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | 0.012    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.395    |
# |    value_loss         | 22.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2818     |
# |    iterations         | 900      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | -0.157   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.589    |
# |    value_loss         | 1.11     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2823     |
# |    iterations         | 1000     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | -0.269   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.335   |
# |    value_loss         | 0.38     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2831     |
# |    iterations         | 1100     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.596   |
# |    explained_variance | -13.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.691    |
# |    value_loss         | 1.95     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2845     |
# |    iterations         | 1200     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.592   |
# |    explained_variance | -0.153   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0069   |
# |    value_loss         | 0.0202   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2849     |
# |    iterations         | 1300     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.485   |
# |    explained_variance | -0.0296  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.548   |
# |    value_loss         | 1.11     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 1400     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.61    |
# |    explained_variance | 0.0132   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.772    |
# |    value_loss         | 3.63     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2875     |
# |    iterations         | 1500     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.0458  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.523    |
# |    value_loss         | 0.792    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2886     |
# |    iterations         | 1600     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.66    |
# |    explained_variance | 0.0507   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 1.67     |
# |    value_loss         | 12.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2895     |
# |    iterations         | 1700     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.68    |
# |    explained_variance | -0.0233  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 10.7     |
# |    value_loss         | 269      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2902     |
# |    iterations         | 1800     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | 0.00424  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -1.55    |
# |    value_loss         | 8.74     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2901     |
# |    iterations         | 1900     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | -60.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.0668   |
# |    value_loss         | 0.00764  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2886     |
# |    iterations         | 2000     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.615   |
# |    explained_variance | 0.0525   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0477   |
# |    value_loss         | 0.128    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2881     |
# |    iterations         | 2100     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.556   |
# |    explained_variance | -0.0231  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.17    |
# |    value_loss         | 0.0432   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2873     |
# |    iterations         | 2200     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | -0.196   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.266   |
# |    value_loss         | 0.437    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2876     |
# |    iterations         | 2300     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | 6.65e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.295    |
# |    value_loss         | 1.22     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2882     |
# |    iterations         | 2400     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | 0.171    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 1.26     |
# |    value_loss         | 4.04     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2886     |
# |    iterations         | 2500     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.462   |
# |    explained_variance | -0.0435  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.986   |
# |    value_loss         | 0.972    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2893     |
# |    iterations         | 2600     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.472   |
# |    explained_variance | -0.00476 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 9.82     |
# |    value_loss         | 122      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2895     |
# |    iterations         | 2700     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.473   |
# |    explained_variance | -0.0374  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.488    |
# |    value_loss         | 1.38     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2898     |
# |    iterations         | 2800     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.319   |
# |    explained_variance | -0.221   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00311  |
# |    value_loss         | 0.00121  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2903     |
# |    iterations         | 2900     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | -0.00546 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.191    |
# |    value_loss         | 2.94     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2907     |
# |    iterations         | 3000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.477   |
# |    explained_variance | -0.0342  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.169   |
# |    value_loss         | 0.373    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2914     |
# |    iterations         | 3100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.768   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.203    |
# |    value_loss         | 0.229    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2916     |
# |    iterations         | 3200     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.467   |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 1.02     |
# |    value_loss         | 4.4      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2916      |
# |    iterations         | 3300      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.493    |
# |    explained_variance | -0.000107 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -0.283    |
# |    value_loss         | 0.168     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2918     |
# |    iterations         | 3400     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.413   |
# |    explained_variance | -12.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0224  |
# |    value_loss         | 0.00272  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2919     |
# |    iterations         | 3500     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.579   |
# |    explained_variance | -0.0258  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -1.26    |
# |    value_loss         | 5.31     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2919     |
# |    iterations         | 3600     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.463   |
# |    explained_variance | 0.00191  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 28.6     |
# |    value_loss         | 2.35e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2912     |
# |    iterations         | 3700     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.626   |
# |    explained_variance | -0.492   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0224  |
# |    value_loss         | 0.00273  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2902     |
# |    iterations         | 3800     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.38    |
# |    explained_variance | -0.00996 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.56    |
# |    value_loss         | 7.01     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2900     |
# |    iterations         | 3900     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | 0.0072   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.945   |
# |    value_loss         | 10.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2903     |
# |    iterations         | 4000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.549   |
# |    explained_variance | -0.225   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.128   |
# |    value_loss         | 0.251    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2906     |
# |    iterations         | 4100     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.505   |
# |    explained_variance | -0.251   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0295   |
# |    value_loss         | 0.00101  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2910     |
# |    iterations         | 4200     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.584   |
# |    explained_variance | -0.149   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0559  |
# |    value_loss         | 0.0204   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2896     |
# |    iterations         | 4300     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.608   |
# |    explained_variance | 0.0661   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.24    |
# |    value_loss         | 0.311    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2900     |
# |    iterations         | 4400     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.642   |
# |    explained_variance | -0.0292  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.269    |
# |    value_loss         | 0.286    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2904     |
# |    iterations         | 4500     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.561   |
# |    explained_variance | 0.0927   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.767    |
# |    value_loss         | 2.48     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2908     |
# |    iterations         | 4600     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.532   |
# |    explained_variance | -0.132   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -6.87    |
# |    value_loss         | 420      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2911     |
# |    iterations         | 4700     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | -0.267   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.164    |
# |    value_loss         | 0.0629   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2914     |
# |    iterations         | 4800     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.626   |
# |    explained_variance | 0.00599  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 4.84     |
# |    value_loss         | 69.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2918     |
# |    iterations         | 4900     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | -0.0782  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -5.8     |
# |    value_loss         | 129      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2921     |
# |    iterations         | 5000     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.657   |
# |    explained_variance | -0.585   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0546   |
# |    value_loss         | 0.0109   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2924     |
# |    iterations         | 5100     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.626   |
# |    explained_variance | -22.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.005   |
# |    value_loss         | 0.00189  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2925     |
# |    iterations         | 5200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.615   |
# |    explained_variance | -0.0396  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.239    |
# |    value_loss         | 0.156    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2924     |
# |    iterations         | 5300     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | 0.0761   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.851    |
# |    value_loss         | 1.76     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2923     |
# |    iterations         | 5400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.649   |
# |    explained_variance | 0.122    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.269   |
# |    value_loss         | 0.388    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2923     |
# |    iterations         | 5500     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | 0.0588   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.219    |
# |    value_loss         | 0.368    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2922      |
# |    iterations         | 5600      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.592    |
# |    explained_variance | -0.000902 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 2.05      |
# |    value_loss         | 97.3      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2924     |
# |    iterations         | 5700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.663   |
# |    explained_variance | -0.00307 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -4.95    |
# |    value_loss         | 109      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2927     |
# |    iterations         | 5800     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | -1.29    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.00902 |
# |    value_loss         | 0.000236 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2930     |
# |    iterations         | 5900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | -0.236   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -7.36    |
# |    value_loss         | 228      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2930     |
# |    iterations         | 6000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | -0.0646  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.133    |
# |    value_loss         | 0.0891   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2933     |
# |    iterations         | 6100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.655   |
# |    explained_variance | 0.243    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.064   |
# |    value_loss         | 0.00845  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2936     |
# |    iterations         | 6200     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.419   |
# |    explained_variance | -0.00299 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.977   |
# |    value_loss         | 5.95     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2939     |
# |    iterations         | 6300     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.482   |
# |    explained_variance | 0.0309   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.11    |
# |    value_loss         | 0.138    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2941     |
# |    iterations         | 6400     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.476   |
# |    explained_variance | 0.00453  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 3.29     |
# |    value_loss         | 12.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2944     |
# |    iterations         | 6500     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 0.00846  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -1.9     |
# |    value_loss         | 6.74     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2945      |
# |    iterations         | 6600      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.59     |
# |    explained_variance | -0.000287 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -11.5     |
# |    value_loss         | 374       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2947     |
# |    iterations         | 6700     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.426   |
# |    explained_variance | -0.00708 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.441   |
# |    value_loss         | 21.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2950     |
# |    iterations         | 6800     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.503   |
# |    explained_variance | -0.443   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.0271  |
# |    value_loss         | 0.0021   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2952     |
# |    iterations         | 6900     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.462   |
# |    explained_variance | 0.0973   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.000371 |
# |    value_loss         | 0.0341   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2951     |
# |    iterations         | 7000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.522   |
# |    explained_variance | -0.464   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.51     |
# |    value_loss         | 0.691    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2950     |
# |    iterations         | 7100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.622   |
# |    explained_variance | -2.67    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.399    |
# |    value_loss         | 0.3      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2940     |
# |    iterations         | 7200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.412   |
# |    explained_variance | -0.00195 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.751   |
# |    value_loss         | 6.16     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2936     |
# |    iterations         | 7300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.552   |
# |    explained_variance | -5.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 1.12     |
# |    value_loss         | 4.37     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2937     |
# |    iterations         | 7400     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.407   |
# |    explained_variance | -0.0131  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -1.21    |
# |    value_loss         | 2.28     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2939     |
# |    iterations         | 7500     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.454   |
# |    explained_variance | 0.0109   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.869    |
# |    value_loss         | 12       |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2941     |
# |    iterations         | 7600     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.54    |
# |    explained_variance | -3.37    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0269  |
# |    value_loss         | 0.00231  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2943     |
# |    iterations         | 7700     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -0.47    |
# |    explained_variance | 0.091    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | -1.62    |
# |    value_loss         | 111      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2944     |
# |    iterations         | 7800     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.378   |
# |    explained_variance | -0.161   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 6.15     |
# |    value_loss         | 58.5     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2942     |
# |    iterations         | 7900     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.296   |
# |    explained_variance | -0.00197 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | -2.49    |
# |    value_loss         | 22.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2943     |
# |    iterations         | 8000     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.434   |
# |    explained_variance | 0.376    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | 0.00869  |
# |    value_loss         | 0.000672 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2945     |
# |    iterations         | 8100     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.393   |
# |    explained_variance | -5.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.00243  |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2947     |
# |    iterations         | 8200     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -0.507   |
# |    explained_variance | -0.0196  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | 2.57     |
# |    value_loss         | 32.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2949     |
# |    iterations         | 8300     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.373   |
# |    explained_variance | -0.437   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 0.203    |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2950     |
# |    iterations         | 8400     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.408   |
# |    explained_variance | -0.136   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -0.156   |
# |    value_loss         | 0.0402   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2951     |
# |    iterations         | 8500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.434   |
# |    explained_variance | -0.0758  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.122    |
# |    value_loss         | 0.189    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2952     |
# |    iterations         | 8600     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -0.41    |
# |    explained_variance | -2.28    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.018   |
# |    value_loss         | 0.00661  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2952      |
# |    iterations         | 8700      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.171    |
# |    explained_variance | -0.478    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.000783 |
# |    value_loss         | 0.000319  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# ...
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 197400   |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 987000   |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | -19.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197399   |
# |    policy_loss        | -0.117   |
# |    value_loss         | 17.3     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 197500   |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 987500   |
# | train/                |          |
# |    entropy_loss       | -0.0987  |
# |    explained_variance | -8.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197499   |
# |    policy_loss        | 0.0112   |
# |    value_loss         | 0.176    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 197600   |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | -0.026   |
# |    explained_variance | -162     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197599   |
# |    policy_loss        | 0.000184 |
# |    value_loss         | 0.154    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 197700   |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 988500   |
# | train/                |          |
# |    entropy_loss       | -0.021   |
# |    explained_variance | -0.119   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197699   |
# |    policy_loss        | -0.00457 |
# |    value_loss         | 0.353    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 197800   |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 989000   |
# | train/                |          |
# |    entropy_loss       | -0.195   |
# |    explained_variance | -2.83    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197799   |
# |    policy_loss        | -0.0119  |
# |    value_loss         | 0.00899  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 197900   |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 989500   |
# | train/                |          |
# |    entropy_loss       | -0.059   |
# |    explained_variance | 0.0376   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197899   |
# |    policy_loss        | -0.135   |
# |    value_loss         | 98.8     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 198000   |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | -0.0784  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 197999   |
# |    policy_loss        | 0.00561  |
# |    value_loss         | 0.21     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2860     |
# |    iterations         | 198100   |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 990500   |
# | train/                |          |
# |    entropy_loss       | -0.00629 |
# |    explained_variance | -0.0054  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198099   |
# |    policy_loss        | 0.0024   |
# |    value_loss         | 5.24     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198200   |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 991000   |
# | train/                |          |
# |    entropy_loss       | -0.0301  |
# |    explained_variance | -9.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198199   |
# |    policy_loss        | -0.00303 |
# |    value_loss         | 0.0955   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198300   |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 991500   |
# | train/                |          |
# |    entropy_loss       | -0.228   |
# |    explained_variance | -0.345   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198299   |
# |    policy_loss        | 0.372    |
# |    value_loss         | 1.38     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198400   |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -0.0003  |
# |    explained_variance | -0.0284  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198399   |
# |    policy_loss        | 0.000399 |
# |    value_loss         | 104      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198500   |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 992500   |
# | train/                |          |
# |    entropy_loss       | -0.00694 |
# |    explained_variance | 0.599    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198499   |
# |    policy_loss        | 1.22e-05 |
# |    value_loss         | 0.00268  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198600   |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 993000   |
# | train/                |          |
# |    entropy_loss       | -0.206   |
# |    explained_variance | 0.129    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198599   |
# |    policy_loss        | -0.00274 |
# |    value_loss         | 0.0219   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198700   |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 993500   |
# | train/                |          |
# |    entropy_loss       | -0.00217 |
# |    explained_variance | -0.0459  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198699   |
# |    policy_loss        | -0.0014  |
# |    value_loss         | 16.4     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198800   |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | -0.204   |
# |    explained_variance | 0.798    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198799   |
# |    policy_loss        | 0.0239   |
# |    value_loss         | 0.045    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 198900   |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 994500   |
# | train/                |          |
# |    entropy_loss       | -0.125   |
# |    explained_variance | 0.474    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198899   |
# |    policy_loss        | -0.155   |
# |    value_loss         | 0.43     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 199000   |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 995000   |
# | train/                |          |
# |    entropy_loss       | -0.0999  |
# |    explained_variance | 0.339    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 198999   |
# |    policy_loss        | 0.116    |
# |    value_loss         | 19.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 199100   |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 995500   |
# | train/                |          |
# |    entropy_loss       | -0.09    |
# |    explained_variance | 0.0105   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199099   |
# |    policy_loss        | 1.6      |
# |    value_loss         | 401      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 199200   |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | -0.0927  |
# |    explained_variance | 0.887    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199199   |
# |    policy_loss        | -0.109   |
# |    value_loss         | 5.02     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2861     |
# |    iterations         | 199300   |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 996500   |
# | train/                |          |
# |    entropy_loss       | -0.145   |
# |    explained_variance | -5.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199299   |
# |    policy_loss        | -0.0186  |
# |    value_loss         | 0.0751   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2862      |
# |    iterations         | 199400    |
# |    time_elapsed       | 348       |
# |    total_timesteps    | 997000    |
# | train/                |           |
# |    entropy_loss       | -0.00282  |
# |    explained_variance | -0.0465   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199399    |
# |    policy_loss        | -0.000891 |
# |    value_loss         | 136       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2862     |
# |    iterations         | 199500   |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 997500   |
# | train/                |          |
# |    entropy_loss       | -0.0139  |
# |    explained_variance | -5.32    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199499   |
# |    policy_loss        | 0.000265 |
# |    value_loss         | 0.0364   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2862     |
# |    iterations         | 199600   |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -0.245   |
# |    explained_variance | -12.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199599   |
# |    policy_loss        | -0.00947 |
# |    value_loss         | 0.0522   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2862     |
# |    iterations         | 199700   |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 998500   |
# | train/                |          |
# |    entropy_loss       | -0.067   |
# |    explained_variance | -4.24    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199699   |
# |    policy_loss        | -0.304   |
# |    value_loss         | 0.298    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2862     |
# |    iterations         | 199800   |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 999000   |
# | train/                |          |
# |    entropy_loss       | -0.167   |
# |    explained_variance | -59.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199799   |
# |    policy_loss        | -0.19    |
# |    value_loss         | 0.903    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2862     |
# |    iterations         | 199900   |
# |    time_elapsed       | 349      |
# |    total_timesteps    | 999500   |
# | train/                |          |
# |    entropy_loss       | -0.129   |
# |    explained_variance | -50.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199899   |
# |    policy_loss        | -0.149   |
# |    value_loss         | 0.263    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2862     |
# |    iterations         | 200000   |
# |    time_elapsed       | 349      |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -0.0123  |
# |    explained_variance | 0.275    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199999   |
# |    policy_loss        | 0.00113  |
# |    value_loss         | 2.35     |
# ------------------------------------
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/fps</td><td>▅▇█▅▅▄▃▃▂▂▂▂▁▁▁▁▂▂▂▁▁▁▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅</td></tr><tr><td>train/entropy_loss</td><td>▁▃▆▆▆▄▇█▇▇███▆██▇█▇█▇████▇█▇███▇▆▇▇▇▆█▇█</td></tr><tr><td>train/explained_variance</td><td>███████████▇██████▄██▁████▇█▇████▅██████</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/policy_loss</td><td>▄▅▃▃▃▁▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃█▃▃▃▃▂▃▃▁▃▃▃▃</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▃█▁▁▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>1000000</td></tr><tr><td>time/fps</td><td>2862.0</td></tr><tr><td>train/entropy_loss</td><td>-0.01235</td></tr><tr><td>train/explained_variance</td><td>0.27494</td></tr><tr><td>train/learning_rate</td><td>0.0007</td></tr><tr><td>train/policy_loss</td><td>0.00113</td></tr><tr><td>train/value_loss</td><td>2.34872</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">northern-galaxy-1</strong>: <a href="https://wandb.ai/full-metal/sb3-Latest/runs/l57u9tn8" target="_blank">https://wandb.ai/full-metal/sb3-Latest/runs/l57u9tn8</a><br/>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230106_125551-l57u9tn8/logs</code>

# %%
# Take actions based on what the agent has learnt with A2C algorithm
env = MyCustomEnv(df=df, window_size=12, frame_bound=(5012,6700))
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_with_signals_A2C.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': 1320.0336835661883, 'total_profit': 0.01184353309581889, 'position': 1}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.legend('PSB')
plt.title('A2C Performance')
plt.show()

# %%
import tensorboard

# %%
tensorboard.version.VERSION

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
# same with PPO and DQN
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 1000000,
    "env_id": "Stocks-v0",
}
run = wandb.init(
    project="sb3-Latest",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)

model_with_signals_PPO = PPO(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}")
model_with_signals_PPO.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        model_save_path=f"models/{run.id}",
        verbose=2,
    ),
)
run.finish()
# Out:
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/Users/rajathdb/D/RL Trading/wandb/run-20230106_130819-132qmzxu</code>
# Syncing run <strong><a href="https://wandb.ai/full-metal/sb3-Latest/runs/132qmzxu" target="_blank">charmed-hill-2</a></strong> to <a href="https://wandb.ai/full-metal/sb3-Latest" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Logging to runs/132qmzxu/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 6798 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4096         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0070480006 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -0.049       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.621        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00502     |
# |    value_loss           | 2.11         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3597         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0037555355 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.000444    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 218          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 406          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3491         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0042152423 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | -0.00442     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 54.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3446         |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0021371127 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | -0.000121    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 287          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3383         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0059146467 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.00397      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 232          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3323         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0047336873 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | -0.0498      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00695     |
# |    value_loss           | 6.3          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3320        |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010590981 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.00225     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 304         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3304         |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0055882866 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | -0.00545     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00533     |
# |    value_loss           | 50.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3292         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0030058238 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | -0.00201     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 297          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3246        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004038362 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | -0.00124    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 134         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3227       |
# |    iterations           | 12         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00865029 |
# |    clip_fraction        | 0.0923     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.651     |
# |    explained_variance   | -0.0644    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.58       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 5.89       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3147         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0071031884 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.000877     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 185          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 349          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3100        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006096689 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | -0.00149    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 26          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3077         |
# |    iterations           | 15           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0031438777 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | 0.00368      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 232          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3076         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0022309218 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | -0.0151      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.4         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00418     |
# |    value_loss           | 130          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3072         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0049537094 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.00422      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.33         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0066      |
# |    value_loss           | 52.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3064         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0060317675 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.00387      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0071      |
# |    value_loss           | 238          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2950         |
# |    iterations           | 19           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0069827116 |
# |    clip_fraction        | 0.0798       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 6.73         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2934         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0066081746 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 5.04e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 235          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 402          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2941        |
# |    iterations           | 21          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003926615 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | -0.000831   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 97.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2942         |
# |    iterations           | 22           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0027493252 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.594       |
# |    explained_variance   | -0.00396     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.8         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00612     |
# |    value_loss           | 90.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2934         |
# |    iterations           | 23           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043680044 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.00404      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 259          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2909         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0061150556 |
# |    clip_fraction        | 0.085        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | -0.0271      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00966     |
# |    value_loss           | 6.3          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2907        |
# |    iterations           | 25          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006770091 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.00117     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 367         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 671         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2908        |
# |    iterations           | 26          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005780382 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | -0.00984    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00773    |
# |    value_loss           | 56.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2906         |
# |    iterations           | 27           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0020955547 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.00335      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 155          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 318          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2909         |
# |    iterations           | 28           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0025175451 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.00209      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.7         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2908         |
# |    iterations           | 29           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0057963366 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.56        |
# |    explained_variance   | -0.00393     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.76         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00763     |
# |    value_loss           | 51.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2903         |
# |    iterations           | 30           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0043818806 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.0048       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 248          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 429          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2907         |
# |    iterations           | 31           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0057979086 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | -0.00217     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.8         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00814     |
# |    value_loss           | 38.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2916        |
# |    iterations           | 32          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.002870135 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.00389     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 306         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2918         |
# |    iterations           | 33           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0039353436 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | -0.0115      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.4         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 114          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2913        |
# |    iterations           | 34          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008884427 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | -0.0131     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.78        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2919         |
# |    iterations           | 35           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0013960014 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.00354      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 382          |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 572          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2927         |
# |    iterations           | 36           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0057795523 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.499       |
# |    explained_variance   | -0.00597     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.28         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00901     |
# |    value_loss           | 18.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2929         |
# |    iterations           | 37           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0022552363 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0.00429      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 188          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 456          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2916        |
# |    iterations           | 38          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004102827 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.00443     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.8        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 101         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2921         |
# |    iterations           | 39           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0043072947 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | 0.0106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.2         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00715     |
# |    value_loss           | 44.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2926         |
# |    iterations           | 40           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0028168713 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0.00926      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00433     |
# |    value_loss           | 275          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2920        |
# |    iterations           | 41          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008090431 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | -0.114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 5.45        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2919        |
# |    iterations           | 42          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.001452731 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.00637     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 330         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2926         |
# |    iterations           | 43           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0033383316 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.000757     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.1         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 53.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2921         |
# |    iterations           | 44           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0016775525 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.00421      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 286          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 257          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2891         |
# |    iterations           | 45           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0032460317 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.0117       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.2         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00539     |
# |    value_loss           | 174          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2889         |
# |    iterations           | 46           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0050040726 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | -0.0993      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00882     |
# |    value_loss           | 6.57         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2885         |
# |    iterations           | 47           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0021221638 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.00699      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 303          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2889         |
# |    iterations           | 48           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0040033385 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.411       |
# |    explained_variance   | 0.00838      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.7         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00463     |
# |    value_loss           | 52.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2892         |
# |    iterations           | 49           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0031794359 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.00906      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72           |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 235          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2894       |
# |    iterations           | 50         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00411453 |
# |    clip_fraction        | 0.0373     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.42      |
# |    explained_variance   | 0.0139     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 72.4       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00514   |
# |    value_loss           | 134        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2899        |
# |    iterations           | 51          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007836713 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.402      |
# |    explained_variance   | -0.00534    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 44          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2903         |
# |    iterations           | 52           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0028077564 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.01         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 173          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 420          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2906        |
# |    iterations           | 53          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.003986943 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.385      |
# |    explained_variance   | 0.0123      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.5        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 37.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2906         |
# |    iterations           | 54           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0019142579 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | 0.0101       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 297          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 383          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2905         |
# |    iterations           | 55           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0049230396 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.396       |
# |    explained_variance   | 0.0119       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.6         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00734     |
# |    value_loss           | 112          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2908        |
# |    iterations           | 56          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005906011 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | 0.0264      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00746    |
# |    value_loss           | 27.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2913         |
# |    iterations           | 57           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0029904277 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | 0.0118       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 520          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2907        |
# |    iterations           | 58          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.006858384 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | -0.0753     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.896       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 6.33        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2909         |
# |    iterations           | 59           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0022785945 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.388       |
# |    explained_variance   | 0.00756      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 415          |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 533          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2909        |
# |    iterations           | 60          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.003136255 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.369      |
# |    explained_variance   | 0.00729     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 89          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2908        |
# |    iterations           | 61          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.002898776 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.368      |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80          |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 295         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2907         |
# |    iterations           | 62           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0019976827 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0.0188       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 168          |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 321          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2910         |
# |    iterations           | 63           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0065305433 |
# ...
# | train/                  |             |
# |    approx_kl            | 0.010448342 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | -0.869      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.27        |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3179         |
# |    iterations           | 473          |
# |    time_elapsed         | 304          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0033252095 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00698     |
# |    value_loss           | 248          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3179         |
# |    iterations           | 474          |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0065460023 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.3         |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00875     |
# |    value_loss           | 86.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3180         |
# |    iterations           | 475          |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0045585185 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.222       |
# |    explained_variance   | 0.273        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.00843     |
# |    value_loss           | 151          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3180         |
# |    iterations           | 476          |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0051003913 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.6         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00945     |
# |    value_loss           | 191          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3180       |
# |    iterations           | 477        |
# |    time_elapsed         | 307        |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.00936929 |
# |    clip_fraction        | 0.0817     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.223     |
# |    explained_variance   | -0.617     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.62       |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 12.9       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3180         |
# |    iterations           | 478          |
# |    time_elapsed         | 307          |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0034808856 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96           |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00617     |
# |    value_loss           | 219          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3180         |
# |    iterations           | 479          |
# |    time_elapsed         | 308          |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0069039585 |
# |    clip_fraction        | 0.0638       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | 0.326        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34           |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 67.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3181        |
# |    iterations           | 480         |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.003615114 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 231         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3181         |
# |    iterations           | 481          |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0040203864 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.2         |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.00855     |
# |    value_loss           | 128          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3180       |
# |    iterations           | 482        |
# |    time_elapsed         | 310        |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.00850234 |
# |    clip_fraction        | 0.0668     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.218     |
# |    explained_variance   | 0.233      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15         |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 50         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3181        |
# |    iterations           | 483         |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.004912834 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00704    |
# |    value_loss           | 247         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3181         |
# |    iterations           | 484          |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0072881766 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.213       |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 37.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3181        |
# |    iterations           | 485         |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.003276743 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 243         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3181         |
# |    iterations           | 486          |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0065288916 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.3         |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3181         |
# |    iterations           | 487          |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0054278523 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.203       |
# |    explained_variance   | 0.259        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00784     |
# |    value_loss           | 60.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3182         |
# |    iterations           | 488          |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0034653181 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.219       |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 183          |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00751     |
# |    value_loss           | 331          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3182        |
# |    iterations           | 489         |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.010165421 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | -0.291      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.9         |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 16.8        |
# -----------------------------------------
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/fps</td><td>█▃▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>train/approx_kl</td><td>▁▃▄▅▂▁▂▂▁▂▄▃▅▅▂▃▁▂▁▂█▅▆▂▂▃▃▂▂▁▆▄▃▃▃▂▂▁▂▇</td></tr><tr><td>train/clip_fraction</td><td>▁▆▄▇▃▃▃▂▂▄▅▅▆▅▄▄▄▃▂▃█▇▇▄▄▅▄▃▄▃▆▅▅▅▅▄▄▃▄▇</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▂▃▄▅▆▆▆▆▅▆▇▇▇▇▇▇▇▇▇██▇▇▇▇▇▇▇▇████████▇█</td></tr><tr><td>train/explained_variance</td><td>▆▆▆▅▆▆▆▆▆▆▆▅▅▇▇▇▇▇▇▇▅▃▇▇▇▇▇▇▇▇▁██████▇█▄</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▄▁▁▁▂▃▃▅▆▇▂▁▁▂▃▃▅▇█▅▁▁▂▃▃▃▄▅▅▆▁▂▂▄▄▇▇▅█▁</td></tr><tr><td>train/policy_gradient_loss</td><td>█▅▄▁▅▆▆▅▆▅▅▄▂▃▅▆▅▅▆▆▂▃▃▅▅▃▄▆▅▅▂▃▄▄▄▄▅▆▅▂</td></tr><tr><td>train/value_loss</td><td>▆▂▂▁▂▂▂▃▅█▂▁▁▂▂▃▃▅▆▅▁▁▂▂▃▃▅▅▆▅▁▂▂▃▃▆▆▆▅▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>1001472</td></tr><tr><td>time/fps</td><td>3182.0</td></tr><tr><td>train/approx_kl</td><td>0.01017</td></tr><tr><td>train/clip_fraction</td><td>0.07505</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-0.20593</td></tr><tr><td>train/explained_variance</td><td>-0.2906</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>7.89881</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.01168</td></tr><tr><td>train/value_loss</td><td>16.82027</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">charmed-hill-2</strong>: <a href="https://wandb.ai/full-metal/sb3-Latest/runs/132qmzxu" target="_blank">https://wandb.ai/full-metal/sb3-Latest/runs/132qmzxu</a><br/>Synced 7 W&B file(s), 0 media file(s), 2 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230106_130819-132qmzxu/logs</code>

# %%
env = MyCustomEnv(df=df, window_size=12, frame_bound=(5012,6700))
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_with_signals_PPO.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': 1368.3254544549436, 'total_profit': 0.006675987074279752, 'position': 1}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.legend('PSB')
plt.title('PPO Performance')
plt.show()

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
from stable_baselines3 import DQN

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 1000000,
    "env_id": "Stocks-v0",
}
run = wandb.init(
    project="sb3-Latest",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  # optional
)

model_with_signals_DQN = DQN(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}")
model_with_signals_DQN.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        model_save_path=f"models/{run.id}",
        verbose=2,
    ),
)
run.finish()
# Out:
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/Users/rajathdb/D/RL Trading/wandb/run-20230106_132246-2s6uvqid</code>
# Syncing run <strong><a href="https://wandb.ai/full-metal/sb3-Latest/runs/2s6uvqid" target="_blank">major-thunder-3</a></strong> to <a href="https://wandb.ai/full-metal/sb3-Latest" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to runs/2s6uvqid/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.24e+03 |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 34949    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.09e+03 |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 35418    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.12e+03 |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 35532    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.19e+03 |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 35577    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.18e+03 |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 35854    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 31940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.636    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 36060    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.13e+03 |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 36142    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 44716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.1e+03  |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 31624    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 51104    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.99e+04 |
# |    n_updates        | 275      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.07e+03 |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 19138    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 57492    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.25e+04 |
# |    n_updates        | 1872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.05e+03 |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 14317    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 63880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.23e+04 |
# |    n_updates        | 3469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.02e+03 |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 11950    |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 70268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.33e+04 |
# |    n_updates        | 5066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.01e+03 |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 10237    |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 76656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.2e+04  |
# |    n_updates        | 6663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.03e+03 |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 9082     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 83044    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88e+04 |
# |    n_updates        | 8260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.15     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 8354     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 89432    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49e+04 |
# |    n_updates        | 9857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.0897   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7708     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 95820    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.37e+04 |
# |    n_updates        | 11454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.09e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 7288     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 102208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.52e+04 |
# |    n_updates        | 13051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.11e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 6896     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 108596   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61e+04 |
# |    n_updates        | 14648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.12e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 6614     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 114984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.63e+04 |
# |    n_updates        | 16245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.11e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 6337     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 121372   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58e+04 |
# |    n_updates        | 17842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.12e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6167     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 127760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25e+04 |
# |    n_updates        | 19439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.14e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6040     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 134148   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e+04 |
# |    n_updates        | 21036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.13e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5907     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 140536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.88e+04 |
# |    n_updates        | 22633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.14e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5801     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 146924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.83e+04 |
# |    n_updates        | 24230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5653     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 153312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04e+04 |
# |    n_updates        | 25827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5561     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 159700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.52e+04 |
# |    n_updates        | 27424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.17e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              |
|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.05e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 4173     |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 926260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.75e+03 |
# |    n_updates        | 219064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 4174     |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 932648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.89e+03 |
# |    n_updates        | 220661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.08e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 4173     |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 939036   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.93e+03 |
# |    n_updates        | 222258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 4174     |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 945424   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.16e+03 |
# |    n_updates        | 223855   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.03e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 4174     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 951812   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78e+03 |
# |    n_updates        | 225452   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.04e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 4174     |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 958200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13e+03 |
# |    n_updates        | 227049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.03e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 4174     |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 964588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.81e+03 |
# |    n_updates        | 228646   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.04e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 4174     |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 970976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09e+03 |
# |    n_updates        | 230243   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.04e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 4174     |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 977364   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.48e+03 |
# |    n_updates        | 231840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.05e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 4169     |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 983752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38e+03 |
# |    n_updates        | 233437   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.05e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 4169     |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 990140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.45e+03 |
# |    n_updates        | 235034   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.04e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 4168     |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 996528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.57e+03 |
# |    n_updates        | 236631   |
# ----------------------------------
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▃▆▄▁▃▄▅▆▆█▇▆▄▃▂▁▁▂▃▃▄▆▆▆▅▆▅▃▃▂▂▂▁▁▂▃▂▂▂▂</td></tr><tr><td>rollout/exploration_rate</td><td>█▇▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>██▇▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▃█▄▃▄▁▁▂▁▁▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>996528</td></tr><tr><td>rollout/ep_len_mean</td><td>1597.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>1044.14185</td></tr><tr><td>rollout/exploration_rate</td><td>0.05</td></tr><tr><td>time/fps</td><td>4168.0</td></tr><tr><td>train/learning_rate</td><td>0.0001</td></tr><tr><td>train/loss</td><td>3574.99609</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">major-thunder-3</strong>: <a href="https://wandb.ai/full-metal/sb3-Latest/runs/2s6uvqid" target="_blank">https://wandb.ai/full-metal/sb3-Latest/runs/2s6uvqid</a><br/>Synced 7 W&B file(s), 0 media file(s), 2 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230106_132246-2s6uvqid/logs</code>

# %%
env = MyCustomEnv(df=df, window_size=12, frame_bound=(5102,6700))
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_with_signals_DQN.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': -138.78607174301283, 'total_profit': 0.41818870347023757, 'position': 0}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.legend('PSB')
plt.title('DQN Performance')
plt.show()

# %%
env.df[5012:6700]
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2015-10-20 00:00:00+05:30   459.562354   460.371938   453.847585   455.609650
# 2015-10-21 00:00:00+05:30   455.038162   464.229410   453.847597   454.800049
# 2015-10-23 00:00:00+05:30   459.062324   463.396038   448.204285   455.109619
# 2015-10-26 00:00:00+05:30   458.086032   458.609909   448.275690   449.013855
# 2015-10-27 00:00:00+05:30   447.085138   451.585517   446.418421   447.442322
# ...                                ...          ...          ...          ...
# 2022-08-16 00:00:00+05:30  2638.256764  2649.323542  2619.413594  2643.341553
# 2022-08-17 00:00:00+05:30  2657.000450  2668.864632  2647.578865  2657.149902
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_with_signals_A2C.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': 222.6488548316779, 'total_profit': 0.4474042136988543, 'position': 0}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.legend('PSB')
plt.title('A2C Yearly Performance')
plt.show()

# %%
env = MyCustomEnv(df=df, window_size=12, frame_bound=(6542,6795))
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_with_signals_PPO.predict(obs)
    obs, rewards, done, info = env.step(action)
    
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': -276.6285154426414, 'total_profit': 0.32496086352405584, 'position': 0}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.legend('PSB')
plt.title('PPO Yearly Performance')
plt.show()

# %%
env = MyCustomEnv(df=df, window_size=12, frame_bound=(6542,6795))
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model_with_signals_DQN.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': 169.41734450946797, 'total_profit': 0.8977434639053239, 'position': 0}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.legend('PSB')
plt.title('DQN Yearly Performance')
plt.show()

# %%
env.df[5102:6700]
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2016-03-02 00:00:00+05:30   472.849162   478.968738   470.158471   476.944763
# 2016-03-03 00:00:00+05:30   480.992748   484.802584   475.039865   482.350006
# 2016-03-04 00:00:00+05:30   482.897636   483.373891   477.897235   479.278290
# 2016-03-08 00:00:00+05:30   479.802131   490.945904   479.802131   489.088623
# 2016-03-09 00:00:00+05:30   485.755014   497.136930   485.088298   496.089233
# ...                                ...          ...          ...          ...
# 2022-08-16 00:00:00+05:30  2638.256764  2649.323542  2619.413594  2643.341553
# 2022-08-17 00:00:00+05:30  2657.000450  2668.864632  2647.578865  2657.149902
# 2022-08-18 00:00:00+05:30  2660.000000  2669.000000  2640.199951  2661.300049
# 2022-08-19 00:00:00+05:30  2650.000000  2661.699951  2604.949951  2613.850098
# 2022-08-22 00:00:00+05:30  2617.000000  2631.300049  2586.000000  2606.600098
#
#                             Volume  Dividends  Stock Splits  SUPERT_7_1.0  \
# Date
# 2016-03-02 00:00:00+05:30  9278900        0.0           0.0    461.386388
# 2016-03-03 00:00:00+05:30  7328829        0.0           0.0    467.231794
# 2016-03-04 00:00:00+05:30  4147803        0.0           0.0    468.976528
# 2016-03-08 00:00:00+05:30  6102409        0.0           0.0    473.713757
# 2016-03-09 00:00:00+05:30  5471034        0.0           0.0    479.396872
# ...                            ...        ...           ...           ...
# 2022-08-16 00:00:00+05:30  3049304        0.0           0.0   2586.633866
# 2022-08-17 00:00:00+05:30  3044037        0.0           0.0   2613.660135
# 2022-08-18 00:00:00+05:30  3419730        8.0           0.0   2613.660135
# 2022-08-19 00:00:00+05:30  4366123        0.0           0.0   2613.660135
# 2022-08-22 00:00:00+05:30  4371179        0.0           0.0   2653.155309
#
#                            SUPERTd_7_1.0  SUPERTl_7_1.0  ...        SMA_5  \
# Date                                                     ...
# 2016-03-02 00:00:00+05:30              1     461.386388  ...   461.362518
